# %%
target = open('00_target.txt').read()
# %env TARGET={target}

# %%
# !wpscan -U usernames.txt -P passwords.txt --url 10.11.1.3

# !wpscan -h
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# Usage: wpscan [options]
#         --url URL                                 The URL of the blog to scan
#                                                   Allowed Protocols: http, https
#                                                   Default Protocol if none provided: http
# ...

# %%
# %env TARGET=http://10.11.1.58/wordpress/
# Out:
# env: TARGET=http://10.11.1.58/wordpress/

# %%
# !wpscan --url $TARGET
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# [+] URL: http://10.11.1.58/wordpress/ [10.11.1.58]
# [+] Started: Thu Oct 28 12:36:31 2021
#
# Interesting Finding(s):
#
# [+] Headers
#  | Interesting Entry: Server: Apache/2.4.18 (Ubuntu)
#  | Found By: Headers (Passive Detection)
#  | Confidence: 100%
#
# [+] XML-RPC seems to be enabled: http://10.11.1.58/wordpress/xmlrpc.php
# ...

# %%
# !wpscan --url $TARGET --api-token zAmWr9FnET5QcAdf2Xcb95xXJDOV7UTvGdNKUua1jLs
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# [+] URL: http://10.11.1.58/wordpress/ [10.11.1.58]
# [+] Started: Thu Oct 28 12:36:45 2021
#
# Interesting Finding(s):
#
# [+] Headers
#  | Interesting Entry: Server: Apache/2.4.18 (Ubuntu)
#  | Found By: Headers (Passive Detection)
#  | Confidence: 100%
#
# [+] XML-RPC seems to be enabled: http://10.11.1.58/wordpress/xmlrpc.php
# ...

# %%
# !wpscan -e u1-20 --url $TARGET
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# [+] URL: http://10.11.1.58/wordpress/ [10.11.1.58]
# [+] Started: Thu Oct 28 12:36:59 2021
#
# Interesting Finding(s):
#
# [+] Headers
#  | Interesting Entry: Server: Apache/2.4.18 (Ubuntu)
#  | Found By: Headers (Passive Detection)
#  | Confidence: 100%
#
# [+] XML-RPC seems to be enabled: http://10.11.1.58/wordpress/xmlrpc.php
# ...

# %%
# !wpscan --url $TARGET -e ap --connect-timeout 240 --request-timeout 240 --detection-mode aggressive --plugins-detection aggressive --plugins-version-detection aggressive
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# [+] URL: http://10.11.1.58/wordpress/ [10.11.1.58]
# [+] Started: Thu Oct 28 12:37:06 2021
#
# Interesting Finding(s):
#
# [+] XML-RPC seems to be enabled: http://10.11.1.58/wordpress/xmlrpc.php
#  | Found By: Direct Access (Aggressive Detection)
#  | Confidence: 100%
#  | References:
# ...

# %%
# !wpscan -U admin -P /usr/share/wordlists/rockyou.txt --url $TARGET
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# [+] URL: http://10.11.1.58/wordpress/ [10.11.1.58]
# [+] Started: Thu Oct 28 13:06:38 2021
#
# Interesting Finding(s):
#
# [+] Headers
#  | Interesting Entry: Server: Apache/2.4.18 (Ubuntu)
#  | Found By: Headers (Passive Detection)
#  | Confidence: 100%
#
# [+] XML-RPC seems to be enabled: http://10.11.1.58/wordpress/xmlrpc.php
# ...
